# %% [markdown]
# https://paper-api.alpaca.markets
#
# PK5XD8GNLWGZR54MF0EZ
#
# R7ti/gvk9mwSalLNUpHEyhTFYz0i5MSrpCSYsx7w

# %%
key_id='PK5XD8GNLWGZR54MF0EZ'
secret_key='R7ti/gvk9mwSalLNUpHEyhTFYz0i5MSrpCSYsx7w'
base_url='https://paper-api.alpaca.markets
# Out:
#   File "<ipython-input-38-598c027b8306>", line 3
#     base_url='https://paper-api.alpaca.markets
#                                               ^
# SyntaxError: EOL while scanning string literal

# %%
import alpaca_trade_api as tradeapi

api = tradeapi.REST('PK5XD8GNLWGZR54MF0EZ', 'R7ti/gvk9mwSalLNUpHEyhTFYz0i5MSrpCSYsx7w', api_version='v2') # or use ENV Vars shown below
account = api.get_account()
api.list_positions()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/Desktop/projects/alpaca/venv/lib/python3.7/site-packages/alpaca_trade_api/rest.py in _one_request(self, method, url, opts, retry)
#     132         try:
# --> 133             resp.raise_for_status()
#     134         except HTTPError as http_error:
#
# ~/Desktop/projects/alpaca/venv/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: Not Found for url: https://api.alpaca.markets/v2/account
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# <ipython-input-1-ba7f2f100d40> in <module>
#       2
# ...

# %%
import alpaca_trade_api as tradeapi

api = tradeapi.REST(
    key_id='PK5XD8GNLWGZR54MF0EZ',
    secret_key='R7ti/gvk9mwSalLNUpHEyhTFYz0i5MSrpCSYsx7w',
    base_url='https://paper-api.alpaca.markets'
)

# Get our position in AAPL.
aapl_position = api.get_position('AAPL')

# Get a list of all of our positions.
portfolio = api.list_positions()

# Print the quantity of shares for each position.
for position in portfolio:
    print("{} shares of {}".format(position.qty, position.symbol))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/Desktop/projects/alpaca/venv/lib/python3.7/site-packages/alpaca_trade_api/rest.py in _one_request(self, method, url, opts, retry)
#     132         try:
# --> 133             resp.raise_for_status()
#     134         except HTTPError as http_error:
#
# ~/Desktop/projects/alpaca/venv/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: Not Found for url: https://paper-api.alpaca.markets/v2/positions/AAPL
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# <ipython-input-2-013049448383> in <module>
#       8
#       9 # Get our position in AAPL.
# ...

# %%
import alpaca_trade_api as tradeapi

api = tradeapi.REST(
    key_id='PK5XD8GNLWGZR54MF0EZ',
    secret_key='R7ti/gvk9mwSalLNUpHEyhTFYz0i5MSrpCSYsx7w',
    base_url='https://paper-api.alpaca.markets'
)

account = api.get_account()
api.list_positions()
# Out:
# []

# %%
print(account)
# Out:
# Account({   'account_blocked': False,
#     'account_number': 'PA2QVDTE3YN2',
#     'buying_power': '400000',
#     'cash': '100000',
#     'created_at': '2019-11-25T18:09:50.86422Z',
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '400000',
#     'equity': '100000',
#     'id': '36893902-e137-455f-a74c-46c381f5804a',
#     'initial_margin': '0',
#     'last_equity': '100000',
#     'last_maintenance_margin': '0',
#     'long_market_value': '0',
#     'maintenance_margin': '0',
#     'multiplier': '4',
#     'pattern_day_trader': False,
#     'portfolio_value': '100000',
#     'regt_buying_power': '200000',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '0',
#     'status': 'ACTIVE',
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False})

# %%
print("${} is your buying power.".format(account.buying_power))
# Out:
# $400000 is your buying power.

# %%
import alpaca_trade_api as tradeapi

api = tradeapi.REST(
    key_id='PK5XD8GNLWGZR54MF0EZ',
    secret_key='R7ti/gvk9mwSalLNUpHEyhTFYz0i5MSrpCSYsx7w',
    base_url='https://paper-api.alpaca.markets'
)


active_assets = api.list_assets(status='active')

# Filter the assets down to just those on NASDAQ.
nasdaq_assets = [a for a in active_assets if a.exchange == 'NASDAQ']
print(nasdaq_assets)
# Out:
# [Asset({   'class': 'us_equity',
#     'easy_to_borrow': True,
#     'exchange': 'NASDAQ',
#     'id': 'bfbe288f-c896-4ceb-a61b-95c6d1b038a8',
#     'marginable': True,
#     'name': '',
#     'shortable': True,
#     'status': 'active',
#     'symbol': 'CLXT',
#     'tradable': True}), Asset({   'class': 'us_equity',
#     'easy_to_borrow': True,
#     'exchange': 'NASDAQ',
#     'id': 'fc85b4c2-6139-40f6-a225-2f67b7eb3645',
#     'marginable': True,
#     'name': '',
#     'shortable': True,
#     'status': 'active',
#     'symbol': 'AROW',
#     'tradable': True}), Asset({   'class': 'us_equity',
#     'easy_to_borrow': True,
#     'exchange': 'NASDAQ',
#     'id': '2106a1a6-7c07-4255-b70a-149fad5d3578',
#     'marginable': True,
#     'name': '',
#     'shortable': True,
#     'status': 'active',
#     'symbol': 'WNEB',
#     'tradable': True}), Asset({   'class': 'us_equity',
#     'easy_to_borrow': True,
#     'exchange': 'NASDAQ',
# ...

# %%
type(nasdaq_assets)
i = nasdaq_assets[0]
print(i)
symbol = i.symbol
print(symbol)
# Out:
# Asset({   'class': 'us_equity',
#     'easy_to_borrow': True,
#     'exchange': 'NASDAQ',
#     'id': 'e2c2a9f9-e4e4-4132-9b5a-0d4a8eb9381c',
#     'marginable': True,
#     'name': '',
#     'shortable': True,
#     'status': 'active',
#     'symbol': 'AMTD',
#     'tradable': True})
# AMTD

# %%
for i in nasdaq_assets:
    symbol = i.symbol
    print(symbol)
# Out:
# AMTD
# CLXT
# WNEB
# EHTH
# AIA
# SITM
# AMHCU
# BXRX
# CTRC
# DFNSU
# DBVT
# SWIR
# IUSG
# PTACU
# PFBC
# CAN
# MUDS
# FFIC
# FNY
# FWRD
# ZYNE
# TACT
# NVEC
# CHPMU
# SAQNU
# IPDN
# MOHO
# SAMG
# SCYX
# BECN
# UXIN
# AMEH
# CSSE
# OVID
# BLDR
# HTGM
# PROF
# PBHC
# ANDE
# GALT
# HCKT
# GNUS
# ABMD
# BGNE
# AVAV
# PSTI
# POTX
# IUSB
# LFUS
# CRWD
# ETON
# UVSP
# EVSTC
# CTG
# LKCO
# PLCE
# WILC
# IMXI
# ACHN
# TELA
# CENTA
# GH
# MERC
# YTRA
# MCMJU
# GILD
# SORL
# INMB
# ARTX
# BGCP
# XON
# FEM
# ENFC
# YMAB
# BKCC
# QADA
# DBX
# IBUY
# RLMD
# ICLK
# VRNT
# AZRX
# FVCB
# DRAD
# POWL
# INVA
# NIHD
# GLAD
# INO
# TORC
# DSKE
# ALLT
# BLMN
# FLEX
# LQDA
# PYZ
# HCAT
# FTXL
# HFWA
# RYAAY
# AMSC
# EBTC
# BEAT
# SUMR
# SBBX
# FTXO
# SESN
# INSM
# CXDC
# GMHIU
# BFIN
# GNCA
# HMHC
# PATK
# CAPR
# SGMA
# KTOS
# UTSI
# FUV
# FTDR
# CENX
# FTXG
# CYAD
# NAVI
# MGTX
# GO
# QTT
# TLF
# LSXMA
# NVCR
# USEG
# UAL
# AKAM
# NOVT
# EPIX
# NEPH
# KOD
# FLWS
# TRIP
# IEUS
# ALGN
# AMRK
# LAZY
# ...

# %%
# Check if AAPL is tradable on the Alpaca platform.
aapl_asset = api.get_asset('AAPL')
if aapl_asset.tradable:
    print('We can trade AAPL.')
# Out:
# We can trade AAPL.

# %%
# Check if the market is open now.
clock = api.get_clock()
print('The market is {}'.format('open.' if clock.is_open else 'closed.'))

# Check when the market was open on Dec. 1, 2018
date = '2018-12-01'
calendar = api.get_calendar(start=date, end=date)[0]
print('The market opened at {} and closed at {} on {}.'.format(
    calendar.open,
    calendar.close,
    date
))
# Out:
# The market is open.
# The market opened at 09:30:00 and closed at 16:00:00 on 2018-12-01.

# %%
# Get daily price data for AAPL over the last 5 trading days.
barset = api.get_barset('AAPL', 'day', limit=5)
aapl_bars = barset['AAPL']

# See how much AAPL moved in that timeframe.
week_open = aapl_bars[0].o
week_close = aapl_bars[-1].c
percent_change = (week_close - week_open) / week_open * 100
print('AAPL moved {}% over the last 5 days'.format(percent_change))
# Out:
# AAPL moved 1.0921087558302665% over the last 5 days

# %%
# Submit a market order to buy 1 share of Apple at market price
api.submit_order(
    symbol='AAPL',
    qty=1,
    side='buy',
    type='market',
    time_in_force='gtc'
)
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': 'b0b6dd9d-8b9b-48a9-ba46-b9d54906e415',
#     'canceled_at': None,
#     'client_order_id': 'a4c487c9-02c2-4ecf-988a-b0e6b7f59436',
#     'created_at': '2019-11-27T18:34:49.2702254Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'id': 'f3a61b40-b7d9-4873-9950-f626669fc192',
#     'limit_price': None,
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'new',
#     'stop_price': None,
#     'submitted_at': '2019-11-27T18:34:49.247801751Z',
#     'symbol': 'AAPL',
#     'time_in_force': 'gtc',
#     'type': 'market',
#     'updated_at': '2019-11-27T18:34:49.27482452Z'})

# %%
# Submit a limit order to attempt to sell 1 share of AMD at a
# particular price ($20.50) when the market opens
api.submit_order(
    symbol='AMD',
    qty=1,
    side='sell',
    type='limit',
    time_in_force='gtc',
    limit_price=39.16
)
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '03fb07bb-5db1-4077-8dea-5d711b272625',
#     'canceled_at': None,
#     'client_order_id': '3fc757f0-52ef-482b-8b60-86118108e83b',
#     'created_at': '2019-11-27T18:36:45.386848885Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'id': 'd4b42424-6907-435e-b40d-2d8b32d369bc',
#     'limit_price': '39.16',
#     'order_type': 'limit',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'sell',
#     'status': 'new',
#     'stop_price': None,
#     'submitted_at': '2019-11-27T18:36:45.327850068Z',
#     'symbol': 'AMD',
#     'time_in_force': 'gtc',
#     'type': 'limit',
#     'updated_at': '2019-11-27T18:36:45.392162564Z'})

# %%
key_id='PK5XD8GNLWGZR54MF0EZ'
secret_key='R7ti/gvk9mwSalLNUpHEyhTFYz0i5MSrpCSYsx7w'

# %%
import alpaca_trade_api as tradeapi
import time

if __name__ == '__main__':
    """
    With the Alpaca API, you can open a short position by submitting a sell
    order for a security that you have no open position with.
    """

    # First, open the API connection
    api = tradeapi.REST(
        key_id,
        secret_key,
        'https://paper-api.alpaca.markets', api_version='v2'
    )

    # The security we'll be shorting
    symbol = 'TSLA'

    # Submit a market order to open a short position of one share
    order = api.submit_order(symbol, 1, 'sell', 'market', 'day')
    print("Market order submitted.")

    # Submit a limit order to attempt to grow our short position
    # First, get an up-to-date price for our symbol
    symbol_bars = api.get_barset(symbol, 'minute', 1).df.iloc[0]
    symbol_price = symbol_bars[symbol]['close']
    # Submit an order for one share at that price
    order = api.submit_order(symbol, 1, 'sell', 'limit', 'day', symbol_price)
    print("Limit order submitted.")

    # Wait a second for our orders to fill...
    print('Waiting...')
    time.sleep(1)

    # Check on our position
    position = api.get_position(symbol)
    if int(position.qty) < 0:
        print(f'Short position open for {symbol}')
# Out:
# Market order submitted.
# Limit order submitted.
# Waiting...
# Short position open for TSLA

# %%
import alpaca_trade_api as tradeapi


# Submit a market order and assign it a Client Order ID.
api.submit_order(
    symbol='AAPL',
    qty=1,
    side='buy',
    type='market',
    time_in_force='gtc',
    client_order_id='my_first_order'
)

# Get our order using its Client Order ID.
my_order = api.get_order_by_client_order_id('my_first_order')
print('Got order #{}'.format(my_order.id))
# Out:
# Got order #74b5f509-a395-4628-9985-0f7b8d957f8c

# %%
import alpaca_trade_api as tradeapi

#api = tradeapi.REST()

# Get the last 100 of our closed orders
closed_orders = api.list_orders(
    status='filled',
    limit=100
)

print(closed_orders)

# Get only the closed orders for a particular stock
closed_aapl_orders = [o for o in closed_orders if o.symbol == 'AAPL']
print(closed_aapl_orders)
# Out:
# [Order({   'asset_class': 'us_equity',
#     'asset_id': 'b0b6dd9d-8b9b-48a9-ba46-b9d54906e415',
#     'canceled_at': None,
#     'client_order_id': 'my_first_order',
#     'created_at': '2019-11-27T19:09:54.896487Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': '2019-11-27T19:09:54.990648Z',
#     'filled_avg_price': '266.89',
#     'filled_qty': '1',
#     'id': '74b5f509-a395-4628-9985-0f7b8d957f8c',
#     'limit_price': None,
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'status': 'filled',
#     'stop_price': None,
#     'submitted_at': '2019-11-27T19:09:54.874488Z',
#     'symbol': 'AAPL',
#     'time_in_force': 'gtc',
#     'type': 'market',
#     'updated_at': '2019-11-27T19:09:54.99851Z'}), Order({   'asset_class': 'us_equity',
#     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#     'canceled_at': None,
# ...

# %%
import alpaca_trade_api as tradeapi

conn = tradeapi.stream2.StreamConn()

# Handle updates on an order you've given a Client Order ID.
# The r indicates that we're listening for a regex pattern.
client_order_id = r'my_client_order_id'
@conn.on(client_order_id)
async def on_msg(conn, channel, data):
    # Print the update to the console.
    print("Update for {}. Event: {}.".format(client_order_id, data['event']))

# Start listening for updates.
conn.run(['trade_updates'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-12ef9cb06f05> in <module>
#       1 import alpaca_trade_api as tradeapi
#       2
# ----> 3 conn = tradeapi.stream2.StreamConn()
#       4
#       5 # Handle updates on an order you've given a Client Order ID.
#
# ~/Desktop/projects/alpaca/venv/lib/python3.7/site-packages/alpaca_trade_api/stream2.py in __init__(self, key_id, secret_key, base_url)
#      12 class StreamConn(object):
#      13     def __init__(self, key_id=None, secret_key=None, base_url=None):
# ---> 14         self._key_id, self._secret_key, _ = get_credentials(key_id, secret_key)
#      15         base_url = re.sub(r'^http', 'ws', base_url or get_base_url())
#      16         self._endpoint = base_url + '/stream'
#
# ...

# %%
import alpaca_trade_api as tradeapi

#api = tradeapi.REST()

# Get our position in AAPL.
aapl_position = api.get_position('AAPL')

# Get a list of all of our positions.
portfolio = api.list_positions()

# Print the quantity of shares for each position.
for position in portfolio:
    print("{} shares of {}".format(position.qty, position.symbol))
# Out:
# -2 shares of TSLA
# 1 shares of NVDA
# -1 shares of AMD
# 2 shares of AAPL

# %%
import alpaca_trade_api as tradeapi
import time

if __name__ == '__main__':
    """
    With the Alpaca API, you can open a short position by submitting a sell
    order for a security that you have no open position with.
    """

    # First, open the API connection
    api = tradeapi.REST(
        key_id,
        secret_key,
        'https://paper-api.alpaca.markets', api_version='v2'
    )

    # The security we'll be shorting
    symbol = 'AAPL'
    
    api.submit_order(
    symbol='AAPL',
    qty=1,
    side='buy',
    type='market',
    time_in_force='gtc'
    )

    # Submit a market order to open a short position of one share
    order = api.submit_order(symbol, 1, 'sell', 'market', 'day')
    print("Market order submitted.")

    # Submit a limit order to attempt to grow our short position
    # First, get an up-to-date price for our symbol
    symbol_bars = api.get_barset(symbol, 'minute', 1).df.iloc[0]
    symbol_price = symbol_bars[symbol]['close']
    # Submit an order for one share at that price
    order = api.submit_order(symbol, 1, 'sell', 'limit', 'day', symbol_price)
    print("Limit order submitted.")

    # Wait a second for our orders to fill...
    print('Waiting...')
    time.sleep(1)

    # Check on our position
    position = api.get_position(symbol)
    if int(position.qty) < 0:
        print(f'Short position open for {symbol}')

# %%
# Get daily price data for AAPL over the last 5 trading days.
barset = api.get_barset('TTD', 'day', limit=50)
aapl_bars = barset['TTD']

# See how much AAPL moved in that timeframe.
hour_open = aapl_bars[0].o
hour_close = aapl_bars[-1].c
percent_change = (hour_close - hour_open) / hour_open * 100
print('AAPL moved {}% over the last 50 days'.format(percent_change))
# Out:
# AAPL moved 26.29581901489118% over the last 50 days

# %%
from pprint import pprint
pprint(barset)
# Out:
# {'XLK': [Bar({'c': 86.885, 'h': 87.06, 'l': 86.82, 'o': 86.94, 't': 1574433000, 'v': 1997}),
#          Bar({'c': 86.785, 'h': 86.82, 'l': 86.785, 'o': 86.82, 't': 1574433900, 'v': 200}),
#          Bar({'c': 86.74, 'h': 86.86, 'l': 86.69, 'o': 86.85, 't': 1574434800, 'v': 3153}),
#          Bar({'c': 86.585, 'h': 86.79, 'l': 86.585, 'o': 86.725, 't': 1574435700, 'v': 7523}),
#          Bar({'c': 86.545, 'h': 86.58, 'l': 86.395, 'o': 86.58, 't': 1574436600, 'v': 3996}),
#          Bar({'c': 86.5, 'h': 86.51, 'l': 86.5, 'o': 86.51, 't': 1574437500, 'v': 101}),
#          Bar({'c': 86.38, 'h': 86.5, 'l': 86.245, 'o': 86.46, 't': 1574438400, 'v': 2001}),
#          Bar({'c': 86.46, 'h': 86.46, 'l': 86.345, 'o': 86.39, 't': 1574439300, 'v': 1500}),
#          Bar({'c': 86.54, 'h': 86.56, 'l': 86.475, 'o': 86.475, 't': 1574440200, 'v': 1856}),
#          Bar({'c': 86.59, 'h': 86.6, 'l': 86.585, 'o': 86.6, 't': 1574441100, 'v': 400}),
# ...

# %%
stock_list = ['SPY','AAPL', 'MSFT', 'TTD', 'LULU']
# Get daily price data for AAPL over the last 5 trading days.

for stock in stock_list:
    barset = api.get_barset(stock, '5Min', limit=50)
    stock_bars = barset[stock]

    # See how much stock moved in that timeframe.
    hour_open = stock_bars[0].o
    hour_close = stock_bars[-1].c
    percent_change = (hour_close - hour_open) / hour_open * 100
    print('{} moved {}% over the last 20 days'.format(stock, percent_change))
# Out:
# SPY moved 0.2176952901544531% over the last 20 days
# AAPL moved 0.24406728747372866% over the last 20 days
# MSFT moved -0.10188989317995144% over the last 20 days
# TTD moved 0.9502728695187609% over the last 20 days
# LULU moved 1.6895647147748039% over the last 20 days

# %%
import time
import alpaca_trade_api as tradeapi

key_id='PK5XD8GNLWGZR54MF0EZ'
secret_key='R7ti/gvk9mwSalLNUpHEyhTFYz0i5MSrpCSYsx7w'

# First, open the API connection
api = tradeapi.REST(
    key_id,
    secret_key,
    'https://paper-api.alpaca.markets', api_version='v2'
)

# Submit a market order to open a short position of one shar
order = api.submit_order(symbol, 1, 'sell', 'market', 'day')

stock_list = ['SPY','AAPL', 'MSFT', 'TTD', 'LULU']

while True:

    for stock in stock_list:
        barset = api.get_barset(stock, '5Min', limit=10)
        stock_bars = barset[stock]
    
        # See how much stock moved in that timeframe.
        hour_open = stock_bars[0].o
        hour_close = stock_bars[-1].c
        percent_change = (hour_close - hour_open) / hour_open * 100
        print('{} moved {}% over the last 50 mins'.format(stock, percent_change))
        
        if percent_change > 1.0:
            print('Taking long position on {}'.format(stock))
            symbol = stock
            api.submit_order(
            symbol= stock,
            qty=1,
            side='buy',
            type='market',
            time_in_force='gtc'
            )
  
        else:
            pass
    print('Sleeping for 5mins')    
    time.sleep(60*5)
    print('-' * 79)
    print('Starting the Algo..')
    print()
# Out:
# SPY moved -0.006342561760689376% over the last 50 mins
# AAPL moved 0.18730450092715728% over the last 50 mins
# MSFT moved 0.06579163788282136% over the last 50 mins
# TTD moved 0.24242424242423727% over the last 50 mins
# LULU moved 0.24684346192495354% over the last 50 mins
# Sleeping for 5mins
# -------------------------------------------------------------------------------
# Starting the Algo..
#
# SPY moved 0.009513842641052091% over the last 50 mins
# AAPL moved 0.1498183452563681% over the last 50 mins
# MSFT moved 0.1250041119773662% over the last 50 mins
# TTD moved 0.06048463312290668% over the last 50 mins
# LULU moved 0.20089090750284216% over the last 50 mins
# Sleeping for 5mins
# -------------------------------------------------------------------------------
# Starting the Algo..
#
# SPY moved -0.009512635951431512% over the last 50 mins
# AAPL moved 0.29594665467896175% over the last 50 mins
# MSFT moved 0.06907667510938337% over the last 50 mins
# ...

# %% [markdown]
# ## Algo Idea
#
# 1) Check price against SPY, if spy moving up, then good to trade
# 2) Get the stock list from the portfolio, any stock movong 1% more than SPY, then add positions until the SPY goes up for the time period.
# 3) When spy turns negative, move the stop loss to -1% loss, if stock price above buying price then move the stop loss to 1cent above the buy price
# 3) If loss is more than 2% close the position
